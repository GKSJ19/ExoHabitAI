# %% [markdown]
# Load Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("datacleaning2_final2.csv")
df.shape
# Out:
# (5954, 11)

# %% [markdown]
# Drop Useless Column

# %%
# Drop junk index column
if "Unnamed: 0" in df.columns:
    df.drop(columns=["Unnamed: 0"], inplace=True)

df.shape
# Out:
# (5954, 10)

# %% [markdown]
# Detect Physically Impossible Values

# %%
# Define physical constraints
constraints = {
    "pl_rad": df["pl_rad"] <= 0,
    "pl_mass": df["pl_mass"] <= 0,
    "pl_sma": df["pl_sma"] <= 0,
    "pl_orbper": df["pl_orbper"] <= 0,
    "st_temp": df["st_temp"] < 0   
}

# Replace impossible values with NaN
for col, condition in constraints.items():
    df.loc[condition, col] = np.nan

# %% [markdown]
# Column-wise Median Imputation (Numerical)

# %%
# Select numerical columns
num_cols = df.select_dtypes(include=["int64", "float64"]).columns

# Median imputation
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

df.isnull().sum()
# Out:
# pl_rad       0
# pl_mass      0
# pl_orbper    0
# pl_sma       0
# pl_ecc       0
# st_temp      0
# st_met       0
# st_rad       0
# st_age       0
# st_mass      0
# dtype: int64

# %% [markdown]
# Categorical Mode Imputation (Future-proof)

# %%
cat_cols = df.select_dtypes(include=["object"]).columns

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
print("Shape:", df.shape)
print("Total missing values:", df.isnull().sum().sum())
df.describe()
# Out:
# Shape: (5954, 10)
# Total missing values: 0
#             pl_rad      pl_mass    pl_orbper       pl_sma       pl_ecc  \
# count  5954.000000  5954.000000  5954.000000  5954.000000  5954.000000
# mean      3.137738   321.535887    27.078043     0.376137     0.113066
# std       2.110888   452.709073    32.499803     0.618100     0.105842
# min       0.309800     0.020000     0.090706     0.004400     0.000000
# 25%       1.920000   176.076938     4.581149     0.082098     0.090000
# 50%       2.438184   176.076938    11.087324     0.114150     0.090000
# 75%       3.070000   176.076938    34.971796     0.168475     0.090000
# max       7.777125  1728.986438    92.086428     2.004842     0.530500
#
#            st_temp       st_met       st_rad       st_age      st_mass
# count  5954.000000  5954.000000  5954.000000  5954.000000  5954.000000
# mean   5366.673559     0.018215     1.017287     4.211106     0.929957
# std     768.911643     0.143508     0.382789     1.634496     0.284697
# min    3442.000000    -0.380000     0.068000     0.001000     0.275000
# 25%    5013.250000    -0.030000     0.800000     4.170000     0.800000
# 50%    5551.000000     0.020000     0.950000     4.170000     0.948000
# 75%    5854.000000     0.060000     1.180000     4.170000     1.071750
# max    7380.000000     0.420000     1.942000     9.225000     1.595000

# %% [markdown]
# Feature Engineering: Habitability Score

# %%
# Enforce realistic astrophysical ranges

df.loc[df["pl_rad"] > 20, "pl_rad"] = np.nan      # >20 Earth radii = likely error
df.loc[df["pl_mass"] > 5000, "pl_mass"] = np.nan # absurd mass
df.loc[df["st_temp"] > 60000, "st_temp"] = np.nan
df.loc[df["pl_sma"] > 100, "pl_sma"] = np.nan    # too far for habitability

# Re-impute after enforcing bounds
for col in df.select_dtypes(include=["float64", "int64"]).columns:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
#  unit validity with sanity bounds

# %%
# Normalize helper
def normalize(series):
    return (series - series.min()) / (series.max() - series.min())

# Temperature score (habitable zone ~ 273–373 K)
temp_score = 1 - abs(df["st_temp"] - 288) / 288

# Planet size similarity to Earth
radius_score = 1 - abs(df["pl_rad"] - 1)

# Orbit stability proxy
orbit_score = normalize(df["pl_sma"])

# Final Habitability Score
df["habitability_score"] = (
    0.4 * temp_score +
    0.3 * radius_score +
    0.3 * orbit_score
)

df["habitability_score"].describe()
# Out:
# count    5954.000000
# mean       -6.943094
# std         1.358335
# min       -11.180213
# 25%        -7.627041
# 50%        -6.990555
# 75%        -6.243836
# max        -3.664097
# Name: habitability_score, dtype: float64

# %%
df["habitable"] = (df["habitability_score"] >= 0.3).astype(int)
df["habitability_score"].min(), df["habitability_score"].max()
df["habitability_score"].isna().sum()
df["habitability_score"].dtype
df["habitability_score"] = pd.to_numeric(df["habitability_score"], errors="coerce")


threshold = df["habitability_score"].quantile(0.8)
df["habitable"] = (df["habitability_score"] >= threshold).astype(int)

df["habitable"].value_counts()
# Out:
# habitable
# 0    4763
# 1    1191
# Name: count, dtype: int64

# %% [markdown]
# Saved clean data

# %%
# Remove duplicate rows
df = df.drop_duplicates()

print("Final shape:", df.shape)
print("Remaining duplicates:", df.duplicated().sum())
# Out:
# Final shape: (5938, 12)
# Remaining duplicates: 0

# %%
total_missing_values = df.isnull().sum().sum()
print("Total missing values:", total_missing_values)
# Out:
# Total missing values: 0

# %%
df.to_csv('pavan.csv')
