# %%
# !python backend/app.py
# Out:
# python: can't open file 'C:\\Users\\Sanjana Malkhede\\Desktop\\Study material\\11PLACEMENT\\infosys internship\\ExoHabitAI\\backend\\backend\\app.py': [Errno 2] No such file or directory

# %%
import requests

url = "http://127.0.0.1:5000/"

requests.get(url).json()
# Out:
# {'message': 'ExoHabitAI Backend is running'}

# %%
import requests
requests.get("http://127.0.0.1:5000/").json()
# Out:
# {'message': 'ExoHabitAI Backend is running'}

# %%
import requests

url = "http://127.0.0.1:5000/predict"

sample_input = {
    "pl_bmasse": 1.0,
    "pl_orbper": 365,
    "pl_orbsmax": 1.0,
    "pl_eqt": 288,
    "pl_dens": 5.5,
    "st_teff": 5778,
    "st_lum": 1.0,
    "st_met": 0.1,

    "st_spectype_G0 V": 1
}

response = requests.post(url, json=sample_input)
response.json()
# Out:
# {'confidence': 0.0261, 'prediction': 0, 'status': 'success'}
